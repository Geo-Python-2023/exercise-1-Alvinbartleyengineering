# %%
ice_cream_rating = 5

# %%
sleeping_rating = 3

# %%
first_name = 'alvin'
last_name = 'bartley'
space = ' '
my_name = first_name + space + last_name
print (my_name)
print (first_name)
# Out:
# alvin bartley
# alvin

# %%
happiness_rating = (ice_cream_rating + sleeping_rating)/2
print(happiness_rating)
# Out:
# 4.0

# %%
happiness_rating_type = type(happiness_rating)
my_name_type = type(my_name)
happines_rating_name = type(happiness_rating)
print(happiness_rating_type, my_name_type, happiness_rating_type)
# Out:
# <class 'float'> <class 'tuple'> <class 'float'>

# %%
# I did not expect to see "tuple' as the type for my_name. I expected to see "str"

# %%
print("My name is", first_name , "and I give eating ice cream a score of", ice_cream_rating, "out of 10")
print ("My name is", my_name, "and my sleeping rating is", sleeping_rating, "out of 10")
print("Based on the factors above my happiness rating is", happiness_rating, "out of 10 or 40%!")
# Out:
# My name is alvin and I give eating ice cream a score of 5 out of 10
# My name is alvin bartley and my sleeping rating is 3 out of 10
# Based on the factors above my happiness rating is 4.0 out of 10 or 40%!
